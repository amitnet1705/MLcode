# %% [markdown]
# # Objective:
#
# The customer's dataset for treadmill product(s) of Cardio Good Fitness retail store should be explored and basic observations about the data to be extracted. Preliminary Data Analysis needs to be carried out.
#
# Following are the main tasks in the analysis :
#
# 1. Come up with a customer profile (characteristics of a customer) of the different products
# 2. Perform uni-variate and multi-variate analyses
# 3. Generate a set of insights and recommendations that will help the company in targeting new customers
#
# # Dataset:
#
# * Product - the model no. of the treadmill
# * Age - in no of years, of the customer
# * Gender - of the customer
# * Education - in no. of years, of the customer
# * Marital Status - of the customer
# * Usage - Avg. # times the customer wants to use the treadmill every week
# * Fitness - Self rated fitness score of the customer (5 - very fit, 1 - very unfit)
# * Income - of the customer
# * Miles- expected to run
#
# # Key questions to be answered:
#
# * What is the age group of customers for each product?
# * Is there a gender inclination in the customer base of each product? Is a particular product used more by men or women?
# * Is there an income category of customers for each product?
# * What is the education profile of customers for each product?
# * For each product is the customer base falling into the married category or the unmarried catgeory?
# * What is the usage for each product?
# * What is the fitness score of customers for each product?
# * What is the avergae miles expected to run on each type of treamill to achieve the fitness levels?

# %% [markdown]
# ### Import the necessary packages - pandas, numpy, seaborn, matplotlib.pyplot

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
sns.set(color_codes=True)

# %% [markdown]
# ### Read in the dataset

# %%
cardiodata = pd.read_csv("D:\course\CARDIOGOODFITNESS.csv")

# %% [markdown]
# ### Shape of the dataset

# %%
cardiodata.shape
# Out:
# (180, 9)

# %% [markdown]
# Observations: There are 180 observations of 9 columns

# %% [markdown]
# ### Check the datatype of the variables

# %%
cardiodata.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %% [markdown]
# Observations:
#
# 1. Product, Gender, Marital Status are of  object data type
# 2. Age, Education, Usage, Fitness, Income, Miles are of integer type

# %% [markdown]
# ### Check the missing values

# %%
cardiodata.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# Observations:
#
# * There are no missing values in any of the 9 columns in the cardio dataset

# %% [markdown]
# ### Columns in the Dataset. Dimensions of the data

# %%
cardiodata.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %% [markdown]
# Observations:
#
# * The main columns of the data are : 'Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage','Fitness', 'Income', 'Miles'

# %% [markdown]
# ### Analysis of the quantitative variables in the cardio dataset

# %%
cardiodata.describe().T
# Out:
#            count          mean           std      min       25%      50%  \
# Age        180.0     28.788889      6.943498     18.0     24.00     26.0
# Education  180.0     15.572222      1.617055     12.0     14.00     16.0
# Usage      180.0      3.455556      1.084797      2.0      3.00      3.0
# Fitness    180.0      3.311111      0.958869      1.0      3.00      3.0
# Income     180.0  53719.577778  16506.684226  29562.0  44058.75  50596.5
# Miles      180.0    103.194444     51.863605     21.0     66.00     94.0
#
#                 75%       max
# Age           33.00      50.0
# Education     16.00      21.0
# Usage          4.00       7.0
# Fitness        4.00       5.0
# Income     58668.00  104581.0
# Miles        114.75     360.0

# %% [markdown]
# Observations:
#
# * The age group of the people using these products are from 18 to 50.The average age of the person using one of the products is 29.
# * Mean value for age is slighlty greater than 50% percentile indicating a slight positive skewness
# * Mean of number of education years is slighlty less than 50% percentile indicating slight negative skewness.
# * The treadmills are used from 2 - 7 hours weekly and on an average 3.5 hours which is between 50% and 75% percentile indicating positive skewness for this data point.
# * The range of fitness score is from 2-7 points with average fitness slightly greater then 50% percentile indicating positive skewness.
# * The range of income of customers is from 29562 - 104581 with average slightly higher the 50% percentile indicating a slight positive skewness
# * Customers/Users are expected to run from 21 - 360 miles. The average number of miles is 103 which is in between 50% and 75% percentile indicating slight positive skewness.

# %%
cardiodata.groupby(['Product']).describe().T
# Out:
# Product                 TM195         TM498          TM798
# Age       count     80.000000     60.000000      40.000000
#           mean      28.550000     28.900000      29.100000
#           std        7.221452      6.645248       6.971738
#           min       18.000000     19.000000      22.000000
#           25%       23.000000     24.000000      24.750000
#           50%       26.000000     26.000000      27.000000
#           75%       33.000000     33.250000      30.250000
#           max       50.000000     48.000000      48.000000
# Education count     80.000000     60.000000      40.000000
#           mean      15.037500     15.116667      17.325000
#           std        1.216383      1.222552       1.639066
#           min       12.000000     12.000000      14.000000
#           25%       14.000000     14.000000      16.000000
#           50%       16.000000     16.000000      18.000000
#           75%       16.000000     16.000000      18.000000
# ...

# %% [markdown]
# Observations:
#
# * TM195 is the most used product with 80 customers.
# * The average age for all the 3 products is roughly the same.
# * The average miles expected to run for TM798 are double the other two products.
# * The average income for TM798 is almost double the other two products.
# * The fitness level for TM798 is 4.625.

# %% [markdown]
# ### Univariate analysis for numerical variables with histograms

# %% [markdown]
# #### Univariate analysis for age

# %%
age = cardiodata['Age']
plt.figure(figsize=(20,10)) 
plt.hist(age, color='g') 
plt.axvline(age.mean(), color='m', linewidth=1)
plt.axvline(age.median(), color='b', linestyle='dashed', linewidth=1)
plt.axvline(age.mode()[0], color='w', linestyle='dashed', linewidth=1)

# %% [markdown]
# Observations:
#
# * In this Age histogram the third bin has the most observations. Maximum number of the customers of these products are between 24-27. Second highest age  group of customers is between 21-24
# * A bulk of observations lie in the first 7 classes. The rest of the 3 classes contain few observations.Most of the users are under 40 years of age. Very few customers above 40.
# * There is positive skewness, mean > median
# * Mean is represented by magenta line, mode by white line and median by blue line.
# * Mode and median are close to each and other and mean is greater than both.
# * This also shows that half the customers are 25 and less based on the median.

# %% [markdown]
# #### Distribution plot for Age bringing out the same observations as above

# %%
sns.distplot(age)
# Out:
# C:\Users\appradha.ORADEV\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
education = cardiodata['Education']
plt.figure(figsize=(20,10)) 
plt.hist(education, color='g') 
plt.axvline(education.mean(), color='m', linewidth=1)
plt.axvline(education.median(), color='b', linestyle='dashed', linewidth=1)
plt.axvline(education.mode()[0], color='w', linestyle='dashed', linewidth=1)

# %% [markdown]
# Observations:
#
# * In this Education histogram the fifth bin has the most observations. Maximum number of the customers of these products have education between 15.5 - 16.5 years
# * A bulk of observations lie in the first 5 bins. The rest of the 5 bins contain few observations. Most of the users have equal to or less then  16.5  years of education. Relatively few customers above 16.5 years of education.
# * Very few customers have more than 20 years of education

# %% [markdown]
# #### Distribution plot for Education bringing out the same observations as above

# %%
sns.distplot(education)
# Out:
# C:\Users\appradha.ORADEV\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Education', ylabel='Density'>

# %%
usage = cardiodata['Usage']
plt.figure(figsize=(20,10))
plt.hist(usage, color='g') 
plt.axvline(usage.mean(), color='m', linewidth=1)
plt.axvline(usage.median(), color='b', linestyle='dashed', linewidth=1)
plt.axvline(usage.mode()[0], color='w', linestyle='dashed', linewidth=1)

# %% [markdown]
# Observations:
#
# * In this Usage histogram the third bin has the most observations. Maximum number of the customers of these products use it for 3-3.5 hours. Second maximum usage is between 4-4.5 hours.
# * A bulk of observations lie in the first 5 bins. The rest of the 5 bins contain few observations.
# * this is also positively skewed.
# * median is somewhere around 3.5 hours and 50% of the customers use it less for 3.5 hours.
# * Very few customers use it between 6 - 7 hours with 6.5- 7 hours the least usage interval

# %% [markdown]
# #### Distribution plot for Usage bringing out the same observations as above

# %%
sns.distplot(usage)
# Out:
# C:\Users\appradha.ORADEV\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Usage', ylabel='Density'>

# %%
fitness = cardiodata['Fitness']
plt.figure(figsize=(20,10)) 
plt.hist(fitness, color='g') 
plt.axvline(fitness.mean(), color='m', linewidth=1)
plt.axvline(fitness.median(), color='b', linestyle='dashed', linewidth=1)
plt.axvline(fitness.mode()[0], color='w', linestyle='dashed', linewidth=1)

# %% [markdown]
# Observations:
#
# * In this fitness histogram the sixth bin has the most observations. Maximum number of the customers have a fitness level between 3 and 3.5 on a scale of 5. Around 30 customers have fitness level between 4 and 5.
# * Very few customers have a fitness level between 1 and 1.5
# * 50% of the people have a fitness level less than 3.4.

# %% [markdown]
# #### Distribution plot for fitness bringing out the same observations as above

# %%
sns.distplot(fitness)
# Out:
# C:\Users\appradha.ORADEV\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fitness', ylabel='Density'>

# %%
income = cardiodata['Income']
plt.figure(figsize=(20,10)) 
plt.hist(income, color='g') 
plt.axvline(income.mean(), color='m', linewidth=1)
plt.axvline(income.median(), color='b', linestyle='dashed', linewidth=1)
plt.axvline(income.mode()[0], color='w', linestyle='dashed', linewidth=1)

# %% [markdown]
# Observations:
#
# * In this income histogram the third bin has the most observations. Maximum number of the customers of these products have an income between 44000-52000. Second highest number of customers fall in the income range of 52000-60000
# * A bulk of observations lie in the first 4 classes. The rest of the 6 classes contain few observations.
# * 50% of the customers have less then 52000 in annual income.
# * Mean is represented by magenta line, mode by white line and median by blue line.
# * Mean and median are close to each and other and mean is greater than both. This is positively skewed.
# * Very few customers have an income above 70000. Most of the customers have an income till 60000.

# %% [markdown]
# #### Distribution plot for income bringing out the same observations as above

# %%
sns.distplot(income);
# Out:
# C:\Users\appradha.ORADEV\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### Univariate analysis for miles

# %%
miles = cardiodata['Miles']
plt.figure(figsize=(20,10)) 
plt.hist(miles, color='g') 
plt.axvline(miles.mean(), color='m', linewidth=1)
plt.axvline(miles.median(), color='b', linestyle='dashed', linewidth=1)
plt.axvline(miles.mode()[0], color='w', linestyle='dashed', linewidth=1)

# %% [markdown]
# Observations:
#
# * In this income histogram the second bin has the most observations. Most number of customers expect to run somewhere between 55-85 miles
# * A bulk of observations lie in the first 5 bins. The rest of the 5 classes contain few observations.
# * 50% of the customers expect to run below 90 miles
# * Mean is represented by magenta line, mode by white line and median by blue line.
# * Mean is greater than both median and mode, this is positively skewed.
# * Most of the customer expect to run till 185 miles
# * Very few customers expect to run above 225 miles

# %% [markdown]
# #### Distribution plot for miles bringing out the same observations as above¶

# %%
sns.distplot(miles);
# Out:
# C:\Users\appradha.ORADEV\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### Relationship between numerical variables using pair plots and correlation plots

# %%
sns.pairplot(cardiodata);

# %%
correlation = cardiodata.corr() # creating a 2-D Matrix with correlation plots
correlation
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(correlation, annot=True, cmap='YlGnBu', vmin=-1, vmax=1);

# %% [markdown]
# Observations:
#
# * Age has positive correlation with income, usage with income, fitness with income, expected miles to run with income, income and usage.
# * There is a high correlation between education and income, fitness and usage, usage and expected miles to run, fitness and miles expected to run.
# * Age does not have a high correlation with any of the dimensions apart from income.
# * Education does not have a high correlation with any of the dimensions apart from income.
# * Income has a high correlation with all the rest of the attributes captured.

# %% [markdown]
# ## Bivariate analysis based on main categorical feature Product

# %% [markdown]
# ### Basic countplot to check which treadmill product is widely used

# %%
sns.countplot(data=cardiodata, x='Product',hue="Gender");

# %% [markdown]
# Observations:-
#
# * Model TM195 is used more in the dataset with 80/180 using it.
# * Model TM798 is least used in the dataset with 40/180 using it.
# * Model TM798 is rarely used by women.
# * Model TM195 is used equally by men and women.

# %% [markdown]
# ### Catplot  to check which treadmill product usage by gender and marital status

# %%
sns.catplot(x="Gender",hue="MaritalStatus",col="Product",data=cardiodata, kind="count");

# %% [markdown]
# Observations:-
#
# * Model TM195 is used more by married women rather than single women.In fact married women in the single largest category of TM195 users
# * Model TM498 is least used by single men.
# * Model TM798 is rarely used by women and in that by single women
#
# ##### * For TM195 married women are the single largest segment of customers
# ##### * For TM195 is used by more married people as compared to single individuals in both men and women. For women the married women using TM 195 is double than single women.
# ##### * For TM798 market segment consists mainly of men
# ##### * For TM498 market segment for married men is double the single men.
# ##### * Overall married people use all three products more than single people.

# %% [markdown]
# ### Catplot to check which treadmill product usage by gender , age and marital status

# %%
sns.catplot(x="Gender",y="Age", hue="MaritalStatus",col="Product",data=cardiodata, kind="box");

# %% [markdown]
# Observations:-
#
# * Model TM195 is used by single males 75% of whom are less than 27 years of age with a 10 year old the youngest to use. 50% of single men to use this model lie between 22-27 years of age with 25% between 25-27 years of age.
# * TM195  is used by married men 50% of whom are in the age of 25-38 , 75% are less than 38 years of age and 25% of whom are in the age of 25-30 years. 25% of married men are in the age range 20-25 years.
# * TM195  is used by single women 50% of whom are in the age of 23-33 , 75% are less than 33 years of age and 25% of whom are in the age of 25-33 years. 25% of single women are in the age range 22-23 years.
# * Model TM195 is used by married women 50% of whom are in the age of 25-29 , 75% are in the age range 18-28 years
# * Model TM498 is  used by single men 50% whom are in the age range 21-27, 75% are less than 27 years.
# * Model TM498 is least used by married men 50% whom are in the age range 23-35, 75% are less than 35 years.
# * Model TM498 is  used by single women 50% whom are in the age range 24-31, 75% are less than 31 years.
# * Model TM498 is least used by married men 50% whom are in the age range 25-34, 75% are less than 34 years.
# * Model TM798 is  used by single men 50% whom are in the age range 23-33, 75% are less than 33 years.
# * Model TM798 is least used by married men 50% whom are in the age range 25-30, 75% are less than 30 years.
# * Model TM798 is  used by single women all of whom are in the range  23-26.
# * Model TM798 is least used by married women 50% whom are in the age range 27-31, 75% are less than 31 years.
#
# ##### * For TM195 even if married women are the single largest segment of customers 50% of them are between 25-30 years¶
# ##### * For TM195 age range of single women is broader than married women.
# ##### * For TM498 market segment age range for married men is broader than single men
# ##### * For TM798 market segment for single men is broader than married men

# %% [markdown]
# ### Catplot to check which treadmill product usage by gender , Education and marital status

# %%
sns.catplot(x="Gender",y="Education", hue="MaritalStatus",col="Product",data=cardiodata, kind="box");

# %%
sns.catplot(x="Gender",y="Education", hue="MaritalStatus",col="Product",data=cardiodata, kind="point");

# %% [markdown]
# Observations:-
#
# * Model TM195 is used by single men 75% of whom have education in the range of 14-16 years.
# * Model TM195 is used by married men 50 % of whom have education in the range of 14-16 years.
# * Model TM195 is used by single women 75% of whom have education in the range of 14-16 years.
# * Model TM195 is used by married women all  having education in the range  of 14-16 years.
# * Model TM498 is used by single men 75% of whom  have education in the age range 14-15.
# * Model TM498 is least used by married men 75% whom have education in the  range 14-16 years.
# * Model TM498 is used by single women 50% whom have education in the  range 14-16 years.
# * Model TM498 is used by married women all of whom have education in the  range 14-16 years.
# * Model TM798 is used by both single and married men 50% whom have education range in 14-16 years.
# * Model TM798 is least used by single women 50% in the range of 17-19.5 years
#
# #### TM 798 is used by more educated people both male and female and married and single.

# %% [markdown]
# ### Catplot to check which treadmill product usage by gender , usage and marital status

# %%
sns.catplot(x="Gender",y="Usage", hue="MaritalStatus",col="Product",data=cardiodata, kind="box");

# %%
sns.catplot(x="Gender",y="Usage", hue="MaritalStatus",col="Product",data=cardiodata, kind="point");

# %%
sns.countplot(data=cardiodata, x='Usage',hue="Product");

# %% [markdown]
# Observations
#
# * TM195 75% of single men use less than 4 hours and 50% of them use between 3-4 hours.
# * TM195 75% of married men use between 3-4 hours
# * TM195 50% of single women use between 3-4 hours and another 50% between 2-3 hours.
# * TM195 75% of married women use between 2-3 hours.
#
# * TM498 75% of single men use between 3-4 hours.
# * TM498 75% of married men use between 2-3 hours.
# * TM498 only 2 single women use and both are outliers.
# * TM498 50% of married women use between 2.5 - 4 hours.
#
# * TM798 50% of single men use between 4-5 hours.
# * TM798 75% of married men use between 4-5.5 hours.
# * TM798 75% of  single women use between 4.5 - 5 hours
# * TM798 75% of married women use between 4.75 and 6 hours.
#
# #### TM 798 average usage is higher than 4.5 times per week and is also higher than other two products for all categories of men and women
# #### TM 195  75% of married men have an usage of 3-4 hours and 75% of married women have an usage between 2-3 hours. 25% of single men have an usage 4-5 hours. 50% of single women have an usage between 2-3 hours and 50% between 3-4 hours.
# #### TM 498  75% of married men have an usage of 2-3 hours where as 75% of single men have an usage betwwen 3-4 hours. All single women apart from 2 outliers have usage of 3 hours. 50% of married women have an usage between 2.5 - 4 hours.

# %% [markdown]
# ### Catplot to check which treadmill product usage by gender , fitness and marital status

# %%
sns.catplot(x="Gender",y="Fitness", hue="MaritalStatus",col="Product",data=cardiodata, kind="box");

# %%
sns.catplot(x="Gender",y="Fitness", hue="MaritalStatus",col="Product",data=cardiodata, kind="point");

# %%
sns.countplot(data=cardiodata, x='Fitness',hue="Product");

# %% [markdown]
# Observations
#
# * TM195 Almost all the men have a fitness ranking of 3 apart from a few outliers.
# * TM195 50% of the married  women are in the range of 2.5 and 3 fitness level. All single women have the fitness level of 3.
# * TM498 Almost all men have a fitness level of 3 apart from few outliers.
# * TM498 50% of single women have a fitness level between 2 - 3. Almost all married women have a fitness level of 3 apart from some outliers
# * TM798 almost all single men are extremely fit with fitness rating of 5. Only 2 outliers.50% of married men have fitness level in range of 4-5.
# * TM798 All married women using the product have a fitness level of 5.
#
# ##### For TM798 the average fitness level for all categories is 4 or above. It is used by the most fit people.
# ##### For TM195 the fitness level is 3 for all categories of men and 3 for all single women apart from some outliers
# ##### For TM498 the fitness level is 3 for all categories of men and 3 for all married women apart from some outliers

# %% [markdown]
# ### Catplot to check which treadmill product usage by gender , income and marital status

# %%
sns.catplot(x="Gender",y="Income", hue="MaritalStatus",col="Product",data=cardiodata, kind="box");

# %%
sns.catplot(x="Gender",y="Income", hue="MaritalStatus",col="Product",data=cardiodata, kind="point");

# %% [markdown]
# Observations
#
# * TM195 50% of single men and women are in the income range of 35000 - 53000
# * TM195 75% of all men and women are below 55000 income range.
# * TM195 highest income figure are not more than 70000 per year.
# * TM498 75% of both men and women are below 52000-53000.
# * TM798 customers are in high income range as compared to other two treadmills. 50% of sinel men are between 50000 - 90000. 50% of married men are between 70000 - 92000.
# * TM798 there is a tangible difference in the income ranges between single women and married women. single women are from 70000-90000 and married women are from 85000-95000.
#
# ##### For TM798 the average income is higher than 55000. It is used by people with more annual income.
# ##### For TM195 the customers have the lowest average income between 42000-50000 as compared to other products. It is used by people with lower annual income.
# ##### For TM498 the average income is close to 50000.

# %% [markdown]
# ### Catplot to check which treadmill product usage by gender , miles expected to run and marital status

# %%
sns.catplot(x="Gender",y="Miles", hue="MaritalStatus",col="Product",data=cardiodata, kind="box");

# %%
sns.catplot(x="Gender",y="Miles", hue="MaritalStatus",col="Product",data=cardiodata, kind="point");

# %% [markdown]
# Observations
#
# * TM195 75% Single men are expected to run 120 miles. 75% of Married men and 75% of all women are expected to use under 100 miles
# * TM498 The range for married women is significantly lower as compared to rest of the three categories.
# * TM798 All categories of users are expected to run for more miles than other two products.
#
# ##### For TM798 the average miles expected to run is more than 125 and is higher than other two products
# ##### For TM195 the average miles expected to run is less 100 or less for both categories of men.
# ##### For TM498 the average miles expected to run is close to 75 for all categories of women.

# %% [markdown]
# ### Conclusions:
#
# ##### TM195 :
#
# * TM195 is the most used product more than the other two.
# * Model TM195 is used equally by men and women.
# * For TM195 married women are the single largest segment of customers.
# * TM195 is used by more married people as compared to single individuals in both men and women. For women the married women using TM 195 is double than single women.
# * For TM195 even if married women are the single largest segment of customers 50% of them are between 25-30 years
# * For TM195 average education is between 14-16 years.
# * TM 195 75% of married men have an usage of 3-4 hours and 75% of married women have an usage between 2-3 hours. 25% of single men have an usage 4-5 hours. 50% of single women have an usage between 2-3 hours and 50% between 3-4 hours.
# * For TM195 the fitness level is 3 for all categories of men and 3 for all single women apart from some outliers.
# * For TM195 the customers have the lowest average income between 42000-50000 as compared to other products. It is used by people with lower annual income.
# * For TM195 the average miles expected to run is less 100 or less for both categories of men.
#
# ##### TM 498 :
#
# * Model TM498 is is used more by married men than single men. The number of married men using this product is double the single men.
# * TM 498 75% of married men have an usage of 2-3 hours where as 75% of single men have an usage betwwen 3-4 hours. All single women apart from 2 outliers have usage of 3 hours. 50% of married women have an usage between 2.5 - 4 hours.
# * For TM498 the average income is close to 50000.
# * For TM498 the fitness level is 3 for all categories of men and 3 for all married women apart from some outliers.
#
# ##### TM 798 :
#
# * For TM798 market segment consists mainly of men. Few women use this product.
# * Model TM798 is least used amongst the 3 treadmills.
# * TM 798 is used by more educated people both men and women and married and single.
# * TM 798 average usage is higher than 4.5 times per week and is also higher than other two products for all categories of men and women
# * For TM798 the average income is higher than 55000. It is used by people with more annual income.
# * For TM798 the average miles expected to run is more than 125 and is higher than other two products.
# * For TM798 the average fitness level for all categories is 4 or above. It is used by the most fit people.
